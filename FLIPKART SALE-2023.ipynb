# %% [markdown]
# # Flipkart MOBILE DATASET-2023

# %% [markdown]
# The dataset includes data on mobile phones from the top five most popular brands in India: Apple, Poco, Realme, Samsung, and Xiaomi. Information like RAM, ROM, Display Size. etc are present which distinguishes one product from another. At least one attribute distinguishes each product.

# %% [markdown]
# ### IN THIS FILE
# - Data Cleaning and Preparation
# -  Statistical Analysis
# -  Predictive Analytics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'F:\SNS ASSI\flipkart_mobile_dataset _2023.csv')
df
# Out:
#                                                   Name     Brand  Rating  RAM  \
# 0                       APPLE iPhone 14 (Blue, 128 GB)     APPLE     4.6    0
# 1                   APPLE iPhone 14 (Midnight, 128 GB)     APPLE     4.6    0
# 2                  APPLE iPhone 14 (Starlight, 128 GB)     APPLE     4.6    0
# 3            SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)   SAMSUNG     4.2    6
# 4           SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)   SAMSUNG     4.2    6
# ..                                                 ...       ...     ...  ...
# 907                                       Snexian Rock   Snexian     4.0    0
# 908           REDMI Note 12 5G (Mystique Blue, 128 GB)     REDMI     4.2    6
# 909                                        Kechaoda K9  Kechaoda     4.1    0
# 910  itel SG400 Keypad Mobile Phone with 9.8mm Ultr...      itel     4.0    0
# 911                                        Kechaoda K9  Kechaoda     4.1    0
#
# ...

# %%
df.head(5)
# Out:
#                                          Name    Brand  Rating  RAM  ROM  \
# 0              APPLE iPhone 14 (Blue, 128 GB)    APPLE     4.6    0  128
# 1          APPLE iPhone 14 (Midnight, 128 GB)    APPLE     4.6    0  128
# 2         APPLE iPhone 14 (Starlight, 128 GB)    APPLE     4.6    0  128
# 3   SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)  SAMSUNG     4.2    6  128
# 4  SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)  SAMSUNG     4.2    6  128
#
#    Battery  Camera    Price
# 0      NaN    36.0  60999.0
# 1      NaN    36.0  61999.0
# 2      NaN    36.0  61999.0
# 3   6000.0    65.0  12490.0
# 4   6000.0    65.0  12490.0

# %% [markdown]
# ## ABOUT THE DATA

# %% [markdown]
# Column | Definition
# --- | ------------
# name | model Name (Categorical)
# brand | brand Name (Categorical)
# ROM | ROM in gigabyte (Numeric – Discrete)
# RAM | RAM in gigabyte (Numeric – Discrete)
# Battery| battery power (Numeric – Continuous)
# ratings | Customer rating for the product (Numeric – Continuous)
# camera| camera total pixel (Numeric – Continuous)
# sales | Sales of product in crore rupees (Numeric – Continuous)

# %% [markdown]
# ### Attributes of the DataSet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     912 non-null    object
#  1   Brand    912 non-null    object
#  2   Rating   900 non-null    float64
#  3   RAM      912 non-null    int64
#  4   ROM      912 non-null    int64
#  5   Battery  726 non-null    float64
#  6   Camera   912 non-null    float64
#  7   Price    909 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 57.1+ KB

# %%
### Checking For missing values

# %%
df.isnull().sum()
# Out:
# Name         0
# Brand        0
# Rating      12
# RAM          0
# ROM          0
# Battery    186
# Camera       0
# Price        3
# dtype: int64

# %%
df["Rating"].unique()
# Out:
# array([4.6, 4.2, 4. , 4.4, 4.3, 4.5, 4.1, 3.9, 3.5, 3.3, 3.1, 3.6, 3.8,
#        3.7, nan, 4.7, 2.6, 3.2, 2.3, 4.8])

# %%
df["Battery"].unique()
# Out:
# array([  nan, 6000., 5000., 4600., 4270., 3700., 4500., 4300., 4400.,
#        4700., 4575., 2500., 4926., 2000., 4980., 1000., 3000., 3300.,
#        1750., 3600., 2700., 1900., 2800., 1450., 4410., 1200., 1700.,
#        2502., 2574., 2575., 1800., 3900., 4800., 2750., 4020., 1150.,
#        5160., 1400.])

# %%
# Fill missing values in the Rating column with the median
df['Rating'].fillna(df['Rating'].median(), inplace=True)

# Fill missing values in the Battery column with the median (or use mean/mode as needed)
df['Battery'].fillna(df['Battery'].median(), inplace=True)

# Fill missing values in the Price column with the mean (or use median/mode as needed)
df['Price'].fillna(df['Price'].mean(), inplace=True)

# Verify that there are no missing values left
print(df.isnull().sum())
# Out:
# Name       0
# Brand      0
# Rating     0
# RAM        0
# ROM        0
# Battery    0
# Camera     0
# Price      0
# dtype: int64
# C:\Users\HOME\AppData\Local\Temp\ipykernel_6832\1596197245.py:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\HOME\AppData\Local\Temp\ipykernel_6832\1596197245.py:5: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ### Description of Numerical Features

# %%
df[['Rating','RAM','ROM','Battery','Camera','Price']].describe()
# Out:
#            Rating         RAM          ROM      Battery       Camera  \
# count  912.000000  912.000000   912.000000   912.000000   912.000000
# mean     4.174123    4.200658   106.707237  4495.599781   101.433936
# std      0.286753    4.211255   105.698704  1308.274559   207.521570
# min      2.300000    0.000000     0.000000  1000.000000     0.000000
# 25%      4.100000    0.000000     0.000000  4675.000000    13.000000
# 50%      4.200000    4.000000   128.000000  5000.000000    58.000000
# 75%      4.300000    8.000000   128.000000  5000.000000    80.500000
# max      4.800000   64.000000  1000.000000  6000.000000  1750.000000
#
#                Price
# count     912.000000
# mean    19825.377338
# std     28346.162924
# min       580.000000
# 25%      1748.000000
# 50%     11247.000000
# 75%     22999.000000
# max    196900.000000

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %% [markdown]
# ### Statistical Analysis

# %% [markdown]
# ### Brand-wise Distinction of Products

# %%
# Group by the Brand column and count the number of products for each brand
brand_wise_count = df.groupby('Brand').size().reset_index(name='Product Count')

# %%
brand_wise_count
# Out:
#          Brand  Product Count
# 0        APPLE             68
# 1     Cellecor              6
# 2         DIZO              3
# 3     Easyfone              1
# 4    Energizer              1
# 5   GREENBERRI              1
# 6         Good              3
# 7       Google             20
# 8      HOTLINE              4
# 9        Honor              2
# 10           I             10
# 11        IAIR             11
# 12        IQOO             10
# 13     Infinix             42
# 14         Jio              2
# 15     KARBONN             28
# 16    Kechaoda             64
# 17        LAVA             14
# 18        Lvix              2
# 19    MOTOROLA             37
# 20         MTR              4
# 21    Micromax             30
# 22       Nokia             33
# 23     Nothing              5
# 24        OPPO             34
# 25     OnePlus             35
# 26        POCO             36
# 27       Peace              1
# 28       REDMI             70
# 29       Redmi              3
# ...

# %%
# Bar plot of product count by brand
plt.figure(figsize=(10, 6))
plt.bar(brand_wise_count['Brand'], brand_wise_count['Product Count'], color='skyblue')
plt.xlabel('Brand')
plt.ylabel('Number of Products')
plt.title('Brand-wise Product Distribution')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Sort the brands by product count in descending order and select the top 10
top_10_brands = brand_wise_count.sort_values(by='Product Count', ascending=False).head(10)
top_10_brands
# Out:
#        Brand  Product Count
# 30   SAMSUNG            100
# 38    realme             75
# 28     REDMI             70
# 0      APPLE             68
# 16  Kechaoda             64
# 40      vivo             56
# 37      itel             44
# 13   Infinix             42
# 19  MOTOROLA             37
# 26      POCO             36

# %%
least_10_brands = brand_wise_count.sort_values(by='Product Count', ascending=True).head(5)
least_10_brands
# Out:
#          Brand  Product Count
# 3     Easyfone              1
# 4    Energizer              1
# 5   GREENBERRI              1
# 27       Peace              1
# 31    SAREGAMA              1

# %%
# Plotting the pie chart
plt.figure(figsize=(10, 7))
plt.pie(top_10_brands['Product Count'], labels=top_10_brands['Brand'], autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Top 10 Brands by Product Count')
plt.show()

# %% [markdown]
# ### INSIGHTS
# - Most options are available from samsung followed by REDMI.
# - samsung has a broad range of phones to select from in terms of specs.
# - Easyfone,Energizer,GREENBERRI	,Peace,SAREGAMA offers the least options given that it is a fairly new brand.

# %% [markdown]
# ### Brand-wise Model Count

# %%
df.head(1)
# Out:
#                              Name  Brand  Rating  RAM  ROM  Battery  Camera  \
# 0  APPLE iPhone 14 (Blue, 128 GB)  APPLE     4.6    0  128   5000.0    36.0
#
#      Price
# 0  60999.0

# %%
brand_wise_model={'Brand':[],'Model_Count':[]}
d={}
for b in df['Brand']:
    df1=df[df['Brand']==b]
    d[b]=len(df1['Name'].value_counts())
brand_wise_model['Brand'].extend(d.keys())
brand_wise_model['Model_Count'].extend(d.values())
dff=pd.DataFrame(brand_wise_model)
dff
# Out:
#          Brand  Model_Count
# 0        APPLE           50
# 1      SAMSUNG           64
# 2         POCO           33
# 3      OnePlus           21
# 4     MOTOROLA           28
# 5         vivo           34
# 6        REDMI           47
# 7       realme           40
# 8      Infinix           28
# 9       Google           15
# 10        OPPO           26
# 11     Nothing            4
# 12     Samsung            4
# 13        itel           30
# 14    Micromax           14
# 15         Jio            2
# 16           I            7
# 17     HOTLINE            2
# 18        LAVA           12
# 19    Kechaoda           22
# 20       Nokia           23
# 21     KARBONN           12
# 22       Tecno           21
# 23       Honor            1
# 24        IQOO            8
# 25        IAIR            4
# 26    Cellecor            3
# 27     Snexian            6
# 28    SAREGAMA            1
# 29        Good            1
# 30       Peace            1
# 31   Energizer            1
# ...

# %%
# Sort the DataFrame by Model_Count in descending order and select the top 10
top_10_brands = dff.sort_values(by='Model_Count', ascending=False).head(10)

# Plotting the bar chart for the top 10 brands
plt.figure(figsize=(12, 8))
plt.bar(top_10_brands['Brand'], top_10_brands['Model_Count'], color='orange')

# Adding labels and title
plt.xlabel('Brand')
plt.ylabel('Number of Distinct Models')
plt.title('Top 10 Brands based on the models no')
plt.xticks(rotation=45, ha='right')  # Rotate brand names for better readability

# Show the plot
plt.show()

# %% [markdown]
# ### INSIGHTS
# - Even though apple has the most product possibilities, Samsung has a lot more distinct mobile phone model.
# - oppo, while being a well-known brand, has the smallest amount of model possibilities.

# %% [markdown]
# ## Top 10 Models

# %%
models={"Model":[],'Count':[]}
dic={}

for m in df['Name']:
    if m in dic:
        dic[m]+=1
    else:
        dic[m]=1

models['Model'].extend(dic.keys())
models['Count'].extend(dic.values())
model_count=pd.DataFrame(models)
top_10_models=model_count.sort_values('Count',ascending=False)[:10]
top_10_models
# Out:
#                                                Model  Count
# 226                                    Kechaoda K115     11
# 52                              SAMSUNG Guru Music 2      8
# 287                                  KARBONN K9 Yuva      6
# 322                                      Kechaoda K9      6
# 13                 vivo T2x 5G (Marine Blue, 128 GB)      6
# 12               vivo T2x 5G (Glimmer Black, 128 GB)      5
# 215                                     Kechaoda A27      5
# 213                                     Kechaoda A26      5
# 200                   Kechaoda K66 The Music House 4      5
# 50   OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)      5

# %%
# Assuming 'top_10_models' is your DataFrame with columns 'Model' and 'Count'
fig, ax = plt.subplots(figsize=(15, 6), dpi=150)

# Assigning 'Model' to 'hue' and disabling the legend
sns.barplot(data=top_10_models, x='Count', y='Model', hue='Model', palette='magma', orient='h', dodge=False, legend=False)

plt.title('Top 10 Models', size=15)
plt.show()

# %% [markdown]
# ### INSIGHTS
# - Kechaoda K115 is the most popular model, as indicated by the longest bar and the darkest color. This model has the highest count among the top 10 models.
# - The second most popular model is SAMSUNG Guru Music 2, followed by KARBONN K9 Yuva. Each model's popularity decreases as you move down the chart.
# - OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB) is the least popular among the top 10, as shown by the shortest and lightest-colored bar.

# %% [markdown]
# ### Which brands have the highest average ratings across their mobile models?

# %%
# Grouping by 'Brand' and calculating the average rating
average_ratings = df.groupby('Brand')['Rating'].mean().reset_index()
# Sorting the brands by their average ratings in descending order
average_ratings = average_ratings.sort_values(by='Rating', ascending=False)
average_ratings.head(5)
# Out:
#       Brand    Rating
# 0     APPLE  4.648529
# 25  OnePlus  4.405714
# 23  Nothing  4.400000
# 40     vivo  4.358929
# 12     IQOO  4.350000

# %% [markdown]
# ### What is the average price of mobile phones by brand?

# %%
avg_price_by_brand = df.groupby('Brand')['Price'].mean().reset_index()

# %%
import matplotlib.pyplot as plt

# Round the prices
avg_price_by_brand['Price'] = avg_price_by_brand['Price'].round(2)

# Sort by price in descending order and select the top 10
top_10_brands = avg_price_by_brand.sort_values(by='Price', ascending=False).head(10)

# Plotting the top 10 brands by average price
plt.figure(figsize=(10, 6))
plt.barh(top_10_brands['Brand'], top_10_brands['Price'], color='skyblue')
plt.xlabel('Average Price (₹)')
plt.ylabel('Brand')
plt.title('Top 10 Brands by Average Price')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest price at the top
plt.show()

# %% [markdown]
# ## insight
# - The bar chart shows the average price for each of these brands, with Apple leading at the highest average price.

# %% [markdown]
# ### What is the distribution of ratings across different brands?

# %%
# Calculate the distribution of ratings across different brands
rating_distribution = df.groupby('Brand')['Rating'].value_counts(normalize=True).unstack().fillna(0)

# Get the top 10 brands based on the total number of ratings
top_10_brands = df['Brand'].value_counts().nlargest(10).index
rating_distribution_top_10 = rating_distribution.loc[top_10_brands]

# Visualize the distribution of ratings across the top 10 brands
plt.figure(figsize=(14, 8))
rating_distribution_top_10.plot(kind='bar', stacked=True, colormap='viridis', figsize=(14, 8))
plt.title('Distribution of Ratings Across Top 10 Brands')
plt.xlabel('Brand')
plt.ylabel('Proportion of Ratings')
plt.legend(title='Rating', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight
# - Apple and Samsung stand out for having the highest proportions of ratings in the upper ranges (e.g., 4.5 to 4.8). Apple's ratings are particularly concentrated in the higher range, suggesting a strong positive customer sentiment.
# - Redmi and Vivo also show strong performance in higher ratings but with more variation than Apple and Samsung.
# - Kechaoda has a more varied distribution, with noticeable proportions of lower ratings (e.g., 3.0 to 4.0). This indicates a mixed customer experience or satisfaction level.
# - Itel and Infinix similarly have significant portions of mid-range ratings, suggesting that while some customers are satisfied, many are less impressed.

# %% [markdown]
# ### How does the price vary with RAM size?

# %%
# Group the data by RAM size and calculate the average price for each RAM size
price_by_ram = df.groupby('RAM')['Price'].mean().reset_index()

# Sort the data by RAM size for better visualization
price_by_ram = price_by_ram.sort_values('RAM')

# Visualize the relationship between RAM size and average price
plt.figure(figsize=(10, 6))
plt.plot(price_by_ram['RAM'], price_by_ram['Price'], marker='o', linestyle='-', color='b')
plt.title('Average Price vs. RAM Size')
plt.xlabel('RAM Size (GB)')
plt.ylabel('Average Price')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Insights:
# - Positive Correlation: Typically, you might see that the price increases as the RAM size increases, reflecting the higher cost associated with larger memory configurations.
# - Price Plateaus: In some cases, the price may plateau or increase less steeply beyond a certain RAM size, indicating diminishing returns on higher RAM configurations.

# %% [markdown]
# ### Which phone has the best rating in the dataset?

# %%
# Find the phone with the highest rating
best_rated_phone = df.loc[df['Rating'].idxmax()]

# Extract phone model and rating
phone_model = best_rated_phone['Name']
rating = best_rated_phone['Rating']

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(phone_model, rating, color='skyblue')
plt.xlabel('Phone Model')
plt.ylabel('Rating')
plt.title('Best Rated Phone')
plt.ylim(0, df['Rating'].max() + 1)  # Set y-axis limit
plt.show()

# %% [markdown]
# ### insight
# -  The bar chart will show the phone model with the highest rating and its value.

# %% [markdown]
# ### BATTERY CAPACITY BOXPLOT AND HISTOGRAM

# %%
fig,axes= plt.subplots(dpi=75)
sns.boxplot(data=df,x='Battery');

# %%
sns.histplot(data=df,x='Battery',kde=True,color='salmon',bins=10);

# %% [markdown]
# ### INSIGHTS
# - Most mobile phones have a battery backup of 5000 mAH.
# - This indicates that 5,000 mAh is a very common battery capacity in the sample.
# ----------------

# %% [markdown]
# ### Selling Price Distribution among the Products

# %%
fig,ax=plt.subplots(figsize=(8,5))
sns.histplot(data=df,x='Price',kde=True,color='salmon',bins=15);

# %% [markdown]
# ### INSIGHTS
# - As expected, most of the products sold are under Rs 20000. There are several outliers in the higher range, therefore the distribution is right skewed.
# ------------

# %%
#df_cleaned = df  # Replace 'df' with your actual DataFrame variable name if different

# Save to CSV
#df_cleaned.to_csv('cleaned_data.csv', index=False)

# %%
# Visualize distributions
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
 #Selecting numerical features
numerical_features = df[['Rating', 'RAM', 'ROM', 'Battery', 'Camera', 'Price']]

# %%
# Correlation matrix
plt.figure(figsize=(12,8))
sns.heatmap(numerical_features.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
# Correlation matrix to understand relationships between numerical features
correlation_matrix = numerical_features.corr()
print(correlation_matrix)
# Out:
#            Rating       RAM       ROM   Battery    Camera     Price
# Rating   1.000000  0.316090  0.548245  0.474705 -0.047743  0.596737
# RAM      0.316090  1.000000  0.475149  0.400137 -0.100589  0.110283
# ROM      0.548245  0.475149  1.000000  0.398687 -0.099468  0.683528
# Battery  0.474705  0.400137  0.398687  1.000000  0.188963  0.214444
# Camera  -0.047743 -0.100589 -0.099468  0.188963  1.000000 -0.066340
# Price    0.596737  0.110283  0.683528  0.214444 -0.066340  1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Calculating VIF to check multicollinearity
vif_data = pd.DataFrame()
vif_data["feature"] = numerical_features.columns
vif_data["VIF"] = [variance_inflation_factor(numerical_features.values, i) for i in range(len(numerical_features.columns))]

# %%
vif_data
# Out:
#    feature        VIF
# 0   Rating  16.027422
# 1      RAM   3.138859
# 2      ROM   5.663159
# 3  Battery  19.645826
# 4   Camera   1.364265
# 5    Price   3.210305

# %%
 #Correlation with the target variable (Price)
correlation_with_target = numerical_features.corr()['Price'].sort_values(ascending=False)
print(correlation_with_target)
# Out:
# Price      1.000000
# ROM        0.683528
# Rating     0.596737
# Battery    0.214444
# RAM        0.110283
# Camera    -0.066340
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,root_mean_squared_error

# %%
# Example: Creating new features or aggregating existing ones
df['price_to_rating_ratio'] = df['Price'] / (df['Rating'] + 1)  # Example feature

# Selecting features and target variable
features = df.drop('Price', axis=1)  
target = df['Price']

# Split data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,root_mean_squared_error

# %%
# Preprocessing for numerical and categorical data
numeric_features = [ 'Rating','RAM','ROM','Battery','Camera', 'price_to_rating_ratio'] 
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())])

# %%
categorical_features = ['Brand', 'Name']  # Example categorical features
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

import pickle

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
# Build the model pipeline
model = Pipeline(steps=[('preprocessor', preprocessor),
                        ('regressor', RandomForestRegressor())])

# %%
# Train the model
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Rating', 'RAM', 'ROM',
#                                                    'Battery', 'Camera',
#                                                    'price_to_rating_ratio']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Brand', 'Name'])])),
#                 ('regressor', RandomForestRegressor())])

# %%
# Make predictions
y_pred = model.predict(x_test)

# Evaluate the model
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R^2 Score:", r2_score(y_test, y_pred))
print("rmse:", root_mean_squared_error (y_test, y_pred))
print("mean_absolute_error:",mean_absolute_error(y_test, y_pred))
# Out:
# Mean Squared Error: 330055.1050668519
# R^2 Score: 0.9994836778967058
# rmse: 574.5042254560465
# mean_absolute_error: 224.48980919403414

# %%
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)
r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)

accuracy_metrics = {'algorithm': RandomForestRegressor.__name__,
                    'R2_train' : r2_train,
                    'R2_test'  : r2_test}

# %%
accuracy_metrics
# Out:
# {'algorithm': 'RandomForestRegressor',
#  'R2_train': 0.9997916736521743,
#  'R2_test': 0.9994836778967058}

# %%
def machine_learning_regression(df, algorithm):

    features = df.drop('Price', axis=1)  
    target = df['Price']

    # Split data into train and test sets
    x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

    model = Pipeline(steps=[('preprocessor', preprocessor),
                        ('regressor', algorithm())])
    model.fit(x_train, y_train)
    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)
    r2_train = r2_score(y_train, y_pred_train)
    r2_test = r2_score(y_test, y_pred_test)

    # algo = str(algorithm).split("'")[1].split(".")[-1]
    accuracy_metrics = {'algorithm': algorithm.__name__,
                        'R2_train' : r2_train,
                        'R2_test'  : r2_test}

    return accuracy_metrics

# %%
print(machine_learning_regression(df, DecisionTreeRegressor))
print(machine_learning_regression(df, ExtraTreesRegressor))
print(machine_learning_regression(df, RandomForestRegressor))
print(machine_learning_regression(df, AdaBoostRegressor))
print(machine_learning_regression(df, GradientBoostingRegressor))
# Out:
# {'algorithm': 'DecisionTreeRegressor', 'R2_train': 1.0, 'R2_test': 0.9996526856120834}
# {'algorithm': 'ExtraTreesRegressor', 'R2_train': 1.0, 'R2_test': 0.9984136273062661}
# {'algorithm': 'RandomForestRegressor', 'R2_train': 0.9998319336748661, 'R2_test': 0.999493648401626}
# {'algorithm': 'AdaBoostRegressor', 'R2_train': 0.9925119049674282, 'R2_test': 0.9900400345496745}
# {'algorithm': 'GradientBoostingRegressor', 'R2_train': 0.999970549214554, 'R2_test': 0.9996198455463935}

# %%
# save the regression model by using pickle

with open('regression_model.pkl', 'wb') as f:
    pickle.dump(model, f)
